# %% [markdown]
# # Geographic data I/O {#read-write}
#
# ## Introduction
#
# ## Retrieving open data
#
# ## Geographic data packages
#
# ## Geographic web services
#
# ## File formats
#
# ## Data input (I)
#
# ### Vector data
#
# ### Raster data
#
# ## Data output (O)
#
# ### Vector data
#
# ### Raster data
#
# ## Visual outputs
#
# ## Exercises
